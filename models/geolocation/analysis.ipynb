# %%
# metrics.py

# %%
import os
import json
import pandas as pd
import unicodedata
from math import radians, sin, cos, sqrt, atan2
import matplotlib.pyplot as plt

# %%
# Process JSON files into dataframe
multiple_views_dir = 'multiple_views'
results = []

# Look for result.json files in multiple_views folder
for root, dirs, files in os.walk(multiple_views_dir):
    for file in files:
        if file == 'result.json':
            file_path = os.path.join(root, file)

            # Load JSON file
            with open(file_path, 'r') as f:
                data = json.load(f)

            # Flatten structure for dataframe
            result = {
                "standpoint_id": data.get("standpoint_id"),
                "gt_coords": data["ground_truth"].get("coords"),
                "gt_continent": data["ground_truth"].get("continent"),
                "gt_country": data["ground_truth"].get("country"),
                "gt_city": data["ground_truth"].get("city"),
                "gt_street": data["ground_truth"].get("street"),
                "gpt_continent": data["gpt_output"]["location"].get("continent"),
                "gpt_country": data["gpt_output"]["location"].get("country"),
                "gpt_city": data["gpt_output"]["location"].get("city"),
                "gpt_street": data["gpt_output"]["location"].get("street"),
                "gpt_reasoning": data["gpt_output"].get("reasoning"),
                "gpt_coords_lat": data["gpt_output"]["coords"].get("lattitude"),
                "gpt_coords_lon": data["gpt_output"]["coords"].get("longitude"),
                "num_adjacent_standpoints": data.get("num_adjacent_standpoints")
            }

            results.append(result)

results_df = pd.DataFrame(results)

# %%
# Process text -- remove accents from strings
# Source: https://stackoverflow.com/questions/517923/what-is-the-best-way-to-remove-accents-normalize-in-a-python-unicode-string
def normalize_text(text):
    return ''.join(
        c for c in unicodedata.normalize('NFKD', text)
        if not unicodedata.combining(c)
    )

# %%
# Process continent/country/city/street
results_df["gt_continent_norm"] = results_df["gt_continent"].apply(normalize_text)
results_df["gpt_continent_norm"] = results_df["gpt_continent"].apply(normalize_text)

results_df["gt_country_norm"] = results_df["gt_country"].apply(normalize_text)
results_df["gpt_country_norm"] = results_df["gpt_country"].apply(normalize_text)

results_df["gt_city_norm"] = results_df["gt_city"].apply(normalize_text)
results_df["gpt_city_norm"] = results_df["gpt_city"].apply(normalize_text)

results_df["gt_street_norm"] = results_df["gt_street"].apply(normalize_text)
results_df["gpt_street_norm"] = results_df["gpt_street"].apply(normalize_text)

# Check if ground truth and GPT values match
results_df["continent_match"] = (results_df["gt_continent_norm"] == results_df["gpt_continent_norm"])
results_df["country_match"] = (results_df["gt_country_norm"] == results_df["gpt_country_norm"])
results_df["city_match"] = (results_df["gt_city_norm"] == results_df["gpt_city_norm"])
results_df["street_match"] = (results_df["gt_street_norm"] == results_df["gpt_street_norm"])

# %%
# Haversine Distance: Gives the shortest distance path between the two points on the surface of the sphere (returns in km)
# Source: https://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points
def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371.0  # earth radius in km
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# wrapper function for error handling and float conversion
def get_haversine_distance(row):
    if row['gpt_coords_lat'] == '' or row['gpt_coords_lon'] == '':
        return None
    
    return haversine_distance(
        float(row['gt_coords_lat']),
        float(row['gt_coords_lon']),
        float(row['gpt_coords_lat']),
        float(row['gpt_coords_lon'])
    )

# %%
# Process ground truth coords
results_df["gt_coords_lat"] = results_df["gt_coords"].apply(lambda x: float(x.split(",")[0]))
results_df["gt_coords_lon"] = results_df["gt_coords"].apply(lambda x: float(x.split(",")[1]))
results_df["gt_gpt_coords_haversine_dist"] = results_df.apply(get_haversine_distance, axis=1)

# %%
# Save results to CSV
results_df.to_csv("results.csv", index=False)
results_df.head(30)
# Out:
#     standpoint_id               gt_coords   gt_continent  gt_country  \
# 0             135    23.750585, 90.388233           Asia  Bangladesh
# 1              61   39.903572, 116.395889           Asia       China
# 2              95     30.045083, 31.24405         Africa       Egypt
# 3             132    23.743157, 90.391069           Asia  Bangladesh
# 4              59     41.402678, 2.181271         Europe       Spain
# 5              92    30.029674, 31.258262         Africa       Egypt
# 6              66   39.910488, 116.416315           Asia       China
# 7             104    22.335455, 91.824697           Asia  Bangladesh
# 8              50   13.775973, 100.480203           Asia    Thailand
# 9              68   39.912866, 116.398192           Asia       China
# 10            103    22.332569, 91.848979           Asia  Bangladesh
# 11             57     41.393565, 2.197059         Europe       Spain
# 12            168   22.320869, 114.206176           Asia   Hong Kong
# 13            157   10.783815, 106.692563           Asia     Vietnam
# 14            150  20.700747, -103.348036  North America      Mexico
# 15            159   10.797122, 106.704562           Asia     Vietnam
# 16             32    33.303188, 44.351337           Asia        Iraq
# 17            166     22.316367, 114.1828           Asia   Hong Kong
# 18             35    33.315755, 44.358297           Asia        Iraq
# 19            161   22.279449, 114.222174           Asia   Hong Kong
# 20            102    22.325248, 91.824767           Asia  Bangladesh
# 21             69   39.913764, 116.395916           Asia       China
# 22             56     41.385986, 2.174627         Europe       Spain
# 23            105    22.337657, 91.849927           Asia  Bangladesh
# 24             51     41.362274, 2.182583         Europe       Spain
# 25             58      41.397213, 2.16714         Europe       Spain
# 26            133    23.743656, 90.369623           Asia  Bangladesh
# 27             67   39.911934, 116.398855           Asia       China
# 28             93     30.03961, 31.230232         Africa       Egypt
# 29            134    23.746995, 90.394314           Asia  Bangladesh
#
#              gt_city                       gt_street  gpt_continent  \
# 0              Dhaka  Bir Uttam Kazi Nuruzzaman Road           Asia
# 1            Beijing       Guangchang West Side Road           Asia
# 2              Cairo                  Mohammed Farid  North America
# 3              Dhaka              Free School Street           Asia
# 4          Barcelona      Carrer del Consell de Cent         Europe
# 5              Cairo                   Salah El-Deen         Africa
# 6            Beijing               Dong Dan San Tiao           Asia
# 7         Chittagong                   Folmondi Road           Asia
# 8            Bangkok                 Atsawin 2 Alley           Asia
# 9            Beijing            Gu Gong Dong Men Wai           Asia
# 10        Chittagong                    Unnamed Road           Asia
# 11         Barcelona        Carrer del Doctor Trueta         Europe
# 12         Hong Kong                 Wang Kwong Road           Asia
# 13  Ho Chi Minh City                         Pasteur           Asia
# 14       Guadalajara    Avenida Fray Antonio Alcalde  North America
# 15  Ho Chi Minh City             Đường Điện Biên Phủ           Asia
# 16           Baghdad                    Unnamed Road           Asia
# 17         Hong Kong                Fat Kwong Street           Asia
# 18           Baghdad                  Mansour Street           Asia
# 19         Hong Kong                   Yiu Hing Road           Asia
# 20        Chittagong                     Strand Road         Africa
# 21           Beijing               Xi Hua Men Da Jie           Asia
# 22         Barcelona               Carrer de Montsió         Europe
# 23        Chittagong                    Unnamed Road           Asia
# 24         Barcelona  Carrer Marítim de Gabriel Roca         Europe
# 25         Barcelona              Carrer de Mallorca         Europe
# 26             Dhaka                        Road 8/A           Asia
# 27           Beijing                    Unnamed Road           Asia
# 28             Cairo                    Ahmed Ragheb         Africa
# 29             Dhaka        Kazi Nazrul Islam Avenue           Asia
#
#    gpt_country            gpt_city  \
# 0   Bangladesh               Dhaka
# 1        China             Beijing
# 2       Mexico         Mexico City
# 3   Bangladesh               Dhaka
# 4        Spain           Barcelona
# 5        Egypt               Cairo
# 6        China             Beijing
# 7   Bangladesh          Chattogram
# 8     Thailand             Bangkok
# 9        China             Beijing
# 10  Bangladesh               Dhaka
# 11       Spain           Barcelona
# 12   Hong Kong  Kwun Tong District
# 13     Vietnam    Ho Chi Minh City
# 14      Mexico         Guadalajara
# 15     Vietnam    Ho Chi Minh City
# 16        Iran              Tehran
# 17   Hong Kong           Hong Kong
# 18        Iraq             Baghdad
# 19   Hong Kong             Kowloon
# 20    Tanzania       Dar es Salaam
# 21       China             Beijing
# 22       Spain           Barcelona
# 23  Bangladesh          Chittagong
# 24       Spain           Barcelona
# 25       Spain           Barcelona
# 26  Bangladesh               Dhaka
# 27       China            Shenyang
# 28       Egypt               Cairo
# 29  Bangladesh               Dhaka
#
#                                            gpt_street  ...  \
# 0                                       Farmgate Area  ...
# 1                            National Museum of China  ...
# 2   Metro Station (likely a major hub like Bellas ...  ...
# 3                                    Residential Area  ...
# 4                                  Carrer de Provença  ...
# 5                                  Salah Salem Street  ...
# 6                             near the Forbidden City  ...
# 7                              Chittagong market area  ...
# 8                                 Ratchadaphisek Road  ...
# 9                                      Forbidden City  ...
# 10                              Old Dhaka Market Area  ...
# 11                                 Carrer de Sardenya  ...
# 12                                       Hoi Bun Road  ...
# 13                                     Pasteur Street  ...
# 14                                       Av. Vallarta  ...
# 15        Likely near a major intersection or street.  ...
# 16                                   Near Milad Tower  ...
# 17                                 Near Tai Hang Road  ...
# 18                         near a government district  ...
# 19                                     Chuk Yuen Road  ...
# 20                                Informal Settlement  ...
# 21                                     Forbidden City  ...
# 22                                  Carrer de Montsió  ...
# 23                    Local Street near a marketplace  ...
# 24                                  Port de Barcelona  ...
# 25                                   Carrer de Girona  ...
# 26                                          Dhanmondi  ...
# 27                               Imperial Palace Area  ...
# 28                                     Unknown Street  ...
# 29                                        Mirpur Road  ...
#
#          gpt_city_norm                  gt_street_norm  \
# 0                Dhaka  Bir Uttam Kazi Nuruzzaman Road
# 1              Beijing       Guangchang West Side Road
# 2          Mexico City                  Mohammed Farid
# 3                Dhaka              Free School Street
# 4            Barcelona      Carrer del Consell de Cent
# 5                Cairo                   Salah El-Deen
# 6              Beijing               Dong Dan San Tiao
# 7           Chattogram                   Folmondi Road
# 8              Bangkok                 Atsawin 2 Alley
# 9              Beijing            Gu Gong Dong Men Wai
# 10               Dhaka                    Unnamed Road
# 11           Barcelona        Carrer del Doctor Trueta
# 12  Kwun Tong District                 Wang Kwong Road
# 13    Ho Chi Minh City                         Pasteur
# 14         Guadalajara    Avenida Fray Antonio Alcalde
# 15    Ho Chi Minh City             Đuong Đien Bien Phu
# 16              Tehran                    Unnamed Road
# 17           Hong Kong                Fat Kwong Street
# 18             Baghdad                  Mansour Street
# 19             Kowloon                   Yiu Hing Road
# 20       Dar es Salaam                     Strand Road
# 21             Beijing               Xi Hua Men Da Jie
# 22           Barcelona               Carrer de Montsio
# 23          Chittagong                    Unnamed Road
# 24           Barcelona  Carrer Maritim de Gabriel Roca
# 25           Barcelona              Carrer de Mallorca
# 26               Dhaka                        Road 8/A
# 27            Shenyang                    Unnamed Road
# 28               Cairo                    Ahmed Ragheb
# 29               Dhaka        Kazi Nazrul Islam Avenue
#
#                                       gpt_street_norm  continent_match  \
# 0                                       Farmgate Area             True
# 1                            National Museum of China             True
# 2   Metro Station (likely a major hub like Bellas ...            False
# 3                                    Residential Area             True
# 4                                  Carrer de Provenca             True
# 5                                  Salah Salem Street             True
# 6                             near the Forbidden City             True
# 7                              Chittagong market area             True
# 8                                 Ratchadaphisek Road             True
# 9                                      Forbidden City             True
# 10                              Old Dhaka Market Area             True
# 11                                 Carrer de Sardenya             True
# 12                                       Hoi Bun Road             True
# 13                                     Pasteur Street             True
# 14                                       Av. Vallarta             True
# 15        Likely near a major intersection or street.             True
# 16                                   Near Milad Tower             True
# 17                                 Near Tai Hang Road             True
# 18                         near a government district             True
# 19                                     Chuk Yuen Road             True
# 20                                Informal Settlement            False
# 21                                     Forbidden City             True
# 22                                  Carrer de Montsio             True
# 23                    Local Street near a marketplace             True
# 24                                  Port de Barcelona             True
# 25                                   Carrer de Girona             True
# 26                                          Dhanmondi             True
# 27                               Imperial Palace Area             True
# 28                                     Unknown Street             True
# 29                                        Mirpur Road             True
#
#    country_match city_match street_match gt_coords_lat gt_coords_lon  \
# 0           True       True        False     23.750585     90.388233
# 1           True       True        False     39.903572    116.395889
# 2          False      False        False     30.045083     31.244050
# 3           True       True        False     23.743157     90.391069
# 4           True       True        False     41.402678      2.181271
# 5           True       True        False     30.029674     31.258262
# 6           True       True        False     39.910488    116.416315
# 7           True      False        False     22.335455     91.824697
# 8           True       True        False     13.775973    100.480203
# 9           True       True        False     39.912866    116.398192
# 10          True      False        False     22.332569     91.848979
# 11          True       True        False     41.393565      2.197059
# 12          True      False        False     22.320869    114.206176
# 13          True       True        False     10.783815    106.692563
# 14          True       True        False     20.700747   -103.348036
# 15          True       True        False     10.797122    106.704562
# 16         False      False        False     33.303188     44.351337
# 17          True       True        False     22.316367    114.182800
# 18          True       True        False     33.315755     44.358297
# 19          True      False        False     22.279449    114.222174
# 20         False      False        False     22.325248     91.824767
# 21          True       True        False     39.913764    116.395916
# 22          True       True         True     41.385986      2.174627
# 23          True       True        False     22.337657     91.849927
# 24          True       True        False     41.362274      2.182583
# 25          True       True        False     41.397213      2.167140
# 26          True       True        False     23.743656     90.369623
# 27          True      False        False     39.911934    116.398855
# 28          True       True        False     30.039610     31.230232
# 29          True       True        False     23.746995     90.394314
#
#    gt_gpt_coords_haversine_dist
# 0                      0.537205
# 1                      0.414527
# 2                  12369.154627
# 3                      7.777935
# 4                      1.676265
# 5                      0.884908
# 6                      1.033004
# 7                      4.888744
# 8                      6.765058
# 9                      0.391104
# 10                   212.687431
# 11                     3.215194
# 12                     3.838319
# 13                     0.760560
# 14                     2.674017
# 15                     2.623956
# 16                   698.149512
# 17                     2.004415
# 18                     0.727684
# 19                     8.061514
# 20                  6571.930752
# 21                     0.302507
# 22                     0.187926
# 23                     7.188305
# 24                     1.151107
# 25                     0.630234
# 26                     1.778316
# 27                   628.434312
# 28                     0.748808
# 29                     0.460748
#
# [30 rows x 29 columns]

# %%
# Calculate basic metrics
total = len(results_df)

# Individual metrics
pct_continent = results_df["continent_match"].mean()
pct_country = results_df["country_match"].mean()
pct_city = results_df["city_match"].mean()
pct_street = results_df["street_match"].mean()

# All wrong 
pct_all_wrong = (~results_df["continent_match"] & ~results_df["country_match"] & ~results_df["city_match"] & ~results_df["street_match"]).mean()

# Continent correct (and country and city wrong)
pct_only_continent_correct = (results_df["continent_match"] & ~results_df["country_match"] & ~ results_df["city_match"] & ~results_df["street_match"]).mean()

# Only continent and country correct (and city wrong)
pct_only_continent_country_correct = (results_df["continent_match"] & results_df["country_match"] & ~results_df["city_match"] & ~results_df["street_match"]).mean()

# Coninenent, country, and city correct
pct_only_continent_country_city_correct = (results_df["continent_match"] & results_df["country_match"] & results_df["city_match"] & ~results_df["street_match"]).mean()

# All correct
pct_all_correct = ((results_df["continent_match"] & results_df["country_match"] & results_df["city_match"] & results_df["street_match"]).mean())

# Continent + country correct but city wrong
pct_continent_country_not_city = ((results_df["continent_match"] & results_df["country_match"] & ~results_df["city_match"]).mean())

# %%
# Overview Statistics
print(f"% Continent correct: {pct_continent:.2%}")
print(f"% Country correct: {pct_country:.2%}")
print(f"% City correct: {pct_city:.2%}")
print(f"% Street correct: {pct_street:.2%}")
print(f"% All wrong: {pct_all_wrong:.2%}")
print(f"% Only continent correct: {pct_only_continent_correct:.2%}")
print(f"% Only continent and country correct: {pct_only_continent_country_correct:.2%}")
print(f"% Only continent, country, and city correct: {pct_only_continent_country_city_correct:.2%}")
print(f"% All correct: {pct_all_correct:.2%}")
print(f"Total number of results: {total}")
# Out:
# % Continent correct: 95.05%
# % Country correct: 85.71%
# % City correct: 75.82%
# % Street correct: 2.75%
# % All wrong: 4.40%
# % Only continent correct: 6.59%
# % Only continent and country correct: 13.19%
# % Only continent, country, and city correct: 69.23%
# % All correct: 2.75%
# Total number of results: 182

# %%
# Commonly missed countries
countries_wrong = results_df[~results_df["country_match"]][['standpoint_id', 'gt_country', 'gpt_country', 'gpt_reasoning', 'continent_match', 'city_match', 'gt_gpt_coords_haversine_dist']]
countries_wrong.head(50)
# Out:
#      standpoint_id   gt_country    gpt_country  \
# 2               95        Egypt         Mexico
# 16              32         Iraq           Iran
# 20             102   Bangladesh       Tanzania
# 32              34         Iraq   Saudi Arabia
# 47              11     Ethiopia          Kenya
# 49               7  Ivory Coast  Côte d'Ivoire
# 65               6  Ivory Coast       Cameroon
# 70               1  Ivory Coast  Côte d'Ivoire
# 71              10  Ivory Coast  Côte d'Ivoire
# 77              21        Egypt         Greece
# 81             119     Tanzania        Country
# 92              38         Iraq         Kuwait
# 96              31         Iraq   Saudi Arabia
# 101            136   Bangladesh       Malaysia
# 113             37         Iraq         France
# 116             39         Iraq         Turkey
# 133            112     Tanzania          Kenya
# 135            115     Tanzania          Kenya
# 145             24        Egypt   Saudi Arabia
# 149             23        Egypt        Tunisia
# 151              4  Ivory Coast  Côte d'Ivoire
# 153              3  Ivory Coast          Kenya
# 159            125        India
# 170              2  Ivory Coast  Côte d'Ivoire
# 173              5  Ivory Coast  Côte d'Ivoire
# 175             14     Ethiopia          Kenya
#
#                                          gpt_reasoning  continent_match  \
# 2    1. The images depict a subway station with dis...            False
# 16   1. **Initial Standpoint:**\n   - The architect...             True
# 20   1. **Initial Viewpoint Analysis**:\n   - The s...            False
# 32   1. The signage in the images is in Arabic, ind...             True
# 47   1. **North View**: Shows a large overpass and ...             True
# 49   1. The environment is tropical, with lush gree...             True
# 65   1. The north view shows a sign for "Hyper U," ...             True
# 70   1. **Language and Signage**: The images have t...             True
# 71   1. The north view shows a road with cars drivi...             True
# 77   1. The images show a large ship dry dock, indi...            False
# 81   1. The images show an interior space with a mo...            False
# 92   1. **Language and Signage**: The signage in th...             True
# 96   1. **Language and Signage**: The signs contain...             True
# 101  1. The images show an indoor parking area with...             True
# 113  1. The environment appears to be an indoor the...            False
# 116  1. The central images depict ancient Assyrian ...            False
# 133  1. The initial north view shows a plain wall, ...             True
# 135  1. The initial viewpoint shows an indoor space...             True
# 145  1. The images show interior views of a mosque,...            False
# 149  1. The street signs in the images are in Arabi...             True
# 151  1. **Language and Signage**: The images show s...             True
# 153  1. The images show a well-maintained park or g...             True
# 159  1. All images appear to be taken indoors in an...            False
# 170  1. **North View**: The image shows a BNI (Banq...             True
# 173  1. The north-facing image shows a bank with th...             True
# 175  1. The architecture of the building with woode...             True
#
#      city_match  gt_gpt_coords_haversine_dist
# 2         False                  12369.154627
# 16        False                    698.149512
# 20        False                   6571.930752
# 32        False                    982.074985
# 47        False                   1165.202915
# 49         True                      2.616681
# 65        False                   1729.589104
# 70         True                      0.820562
# 71         True                      2.027527
# 77        False                    944.082039
# 81        False                           NaN
# 92        False                    558.474200
# 96        False                    980.472325
# 101       False                   2595.071936
# 113       False                   3856.991087
# 116       False                   1606.532013
# 133       False                    671.812254
# 135       False                    671.977857
# 145       False                   1211.817021
# 149       False                   1828.163177
# 151        True                      1.599570
# 153       False                   4594.523156
# 159       False                           NaN
# 170        True                      0.587596
# 173        True                      2.053964
# 175       False                   1168.237424

# %%
# Top wrong countries
countries_wrong['gt_country'].value_counts().reset_index(name='count')
# Out:
#     gt_country  count
# 0  Ivory Coast      8
# 1         Iraq      6
# 2        Egypt      4
# 3     Tanzania      3
# 4   Bangladesh      2
# 5     Ethiopia      2
# 6        India      1

# %%
# Top wrong countries (and what GPT guessed)
wrong_grouped = countries_wrong.groupby(['gt_country', 'gpt_country']).size().reset_index(name='count')
wrong_grouped = wrong_grouped.sort_values('count', ascending=False)
wrong_grouped.head(20)
# Out:
#      gt_country    gpt_country  count
# 14  Ivory Coast  Côte d'Ivoire      6
# 17     Tanzania          Kenya      2
# 6      Ethiopia          Kenya      2
# 11         Iraq   Saudi Arabia      2
# 10         Iraq         Kuwait      1
# 16     Tanzania        Country      1
# 15  Ivory Coast          Kenya      1
# 13  Ivory Coast       Cameroon      1
# 12         Iraq         Turkey      1
# 0    Bangladesh       Malaysia      1
# 1    Bangladesh       Tanzania      1
# 8          Iraq         France      1
# 7         India                     1
# 5         Egypt        Tunisia      1
# 4         Egypt   Saudi Arabia      1
# 3         Egypt         Mexico      1
# 2         Egypt         Greece      1
# 9          Iraq           Iran      1

# %%
# Commonly missed cities (where country is correct)
cities_wrong = results_df[~results_df["city_match"] & results_df['country_match']][['standpoint_id', 'gt_city', 'gpt_city', 'gpt_reasoning', 'continent_match', 'country_match', 'gt_gpt_coords_haversine_dist']]
cities_wrong.head(50)
# Out:
#      standpoint_id        gt_city            gpt_city  \
# 7              104     Chittagong          Chattogram
# 10             103     Chittagong               Dhaka
# 12             168      Hong Kong  Kwun Tong District
# 19             161      Hong Kong             Kowloon
# 27              67        Beijing            Shenyang
# 36             167      Hong Kong             Kowloon
# 52             129          Delhi           New Delhi
# 59             118  Dar es Salaam       Zanzibar City
# 61             127          Delhi           New Delhi
# 80             121          Delhi           New Delhi
# 84             126          Delhi           New Delhi
# 88             128          Delhi           New Delhi
# 97             165      Hong Kong             Kowloon
# 104            109     Chittagong               Dhaka
# 107            107     Chittagong               Dhaka
# 112            164      Hong Kong             Kowloon
# 114            163      Hong Kong    Victoria Harbour
# 126            108     Chittagong               Dhaka
# 128            130          Delhi           New Delhi
# 129             64        Beijing               Xi'an
# 138            123          Delhi           New Delhi
# 142            124          Delhi           New Delhi
# 148            148    Guadalajara         Mexico City
# 163            122          Delhi           New Delhi
#
#                                          gpt_reasoning  continent_match  \
# 7    1. **Language and Scripts**: The signs in the ...             True
# 10   1. **Language and Signage**: The signs and pos...             True
# 12   1. **Language and Signage**: The use of Chines...             True
# 19   1. The images show a high-density urban area w...             True
# 27   1. The north and south views show traditional ...             True
# 36   1. **Architecture and Signage**: The presence ...             True
# 52   1. **Language and Road Signs**: The signs are ...             True
# 59   1. The architectural style seen in the images ...             True
# 61   1. **Road and Traffic Analysis**: The images s...             True
# 80   1. **Language and Signs:** The signs are in Hi...             True
# 84   1. The architecture style of the building with...             True
# 88   1. **Architecture and Surroundings**: The buil...             True
# 97   1. The architecture in the northern view shows...             True
# 104  1. **Language and Signs**: The signage observe...             True
# 107  1. **Language and Text**: The text on the mura...             True
# 112  1. The signage across the images is in Chinese...             True
# 114  1. All four images display a densely built urb...             True
# 126  1. **Language and Signage:** The signs and pos...             True
# 128  1. The interior of the office space has a mode...             True
# 129  1. The north view shows a statue of a man with...             True
# 138  1. The images show a lush environment with lar...             True
# 142  1. The north view shows an amphitheater-like s...             True
# 148  1. **Language and Signs**: The signs in the in...             True
# 163  1. The images show a busy urban area with abun...             True
#
#      country_match  gt_gpt_coords_haversine_dist
# 7             True                      4.888744
# 10            True                    212.687431
# 12            True                      3.838319
# 19            True                      8.061514
# 27            True                    628.434312
# 36            True                      2.675762
# 52            True                      0.577487
# 59            True                     73.724354
# 61            True                      2.640543
# 80            True                      7.944749
# 84            True                      9.070021
# 88            True                      1.354979
# 97            True                      3.666431
# 104           True                    215.909076
# 107           True                    218.070035
# 112           True                      2.959618
# 114           True                      0.898203
# 126           True                    218.413138
# 128           True                      2.568286
# 129           True                    910.890752
# 138           True                      0.623117
# 142           True                      0.231394
# 148           True                    463.417030
# 163           True                      5.172937

# %%
# Top wrong cities (and what GPT guessed)
cities_wrong_grouped = cities_wrong.groupby(['gt_city', 'gpt_city']).size().reset_index(name='count')
cities_wrong_grouped = cities_wrong_grouped.sort_values('count', ascending=False)
cities_wrong_grouped.head(20)
# Out:
#          gt_city            gpt_city  count
# 5          Delhi           New Delhi      9
# 3     Chittagong               Dhaka      4
# 7      Hong Kong             Kowloon      4
# 0        Beijing            Shenyang      1
# 1        Beijing               Xi'an      1
# 2     Chittagong          Chattogram      1
# 4  Dar es Salaam       Zanzibar City      1
# 6    Guadalajara         Mexico City      1
# 8      Hong Kong  Kwun Tong District      1
# 9      Hong Kong    Victoria Harbour      1

# %%
# Histogram of Haversine distances 
plt.hist(results_df["gt_gpt_coords_haversine_dist"], bins=20, edgecolor='black')
plt.title("Histogram of Haversine Distances (All)")
plt.xlabel("Distance (km)")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram of Haversine distances (< 50km)
filtered_df = results_df[results_df['gt_gpt_coords_haversine_dist'] < 50]
plt.hist(filtered_df["gt_gpt_coords_haversine_dist"], bins=25, edgecolor='black')
plt.title("Histogram of Haversine Distances (< 50 km)")
plt.xlabel("Distance (km)")
plt.ylabel("Frequency")
plt.show()
